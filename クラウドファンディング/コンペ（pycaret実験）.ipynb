# %%
import pandas as pd 
import numpy as np

df_train_trans=pd.read_csv('train_trans.csv')
df_test_trans=pd.read_csv('test_trans.csv')

# %%
df_train_trans['html_content'][20]
# Out:
# " Demons Of Asteborg is a new original title for the SEGA Mega Drive / Genesis which will be released as a physical cartridge and also a downloadable ROM for emulators and flash cards. Moreover, we plan to port the game on the Nintendo Switch and Steam..GET THE DEMO HERE ! It is a platform-based game with some metroidvania elements inspired by a lot of other Mega Drive / Genesis titles like Ghouls'n Ghosts, Castlevania, Mickey Mania, Space Harrier or Panzer Dragoon. Demons of Asteborg title screen We are passionate about retro-gaming and we love trying to push the Mega Drive to the limits of its capabilities. The game is still at the prototype stage in the current state but we really want to see it out on the Mega Drive in 2020, that's why we need the funding generated by Kickstarter to remunerate our developers, and the artists we working with, in order to complete the game and make it accessible as quickly as possible..OST track (Cemetary) :         .soundcloud .card {.          ma
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
from pycaret.classification import *
df_train_trans=df_train_trans.drop('html_content',axis=1)
exp1 = setup(df_train_trans, target = 'state')

compare_models()
# Out:
# <style  type="text/css" >
#     #T_2b6f01a4_63c4_11eb_b618_acde48001122 th {
#           text-align: left;
# ...

# %%
model1 = create_model('lda')
model2 = create_model('xgboost')
model3 = create_model('lightgbm')
model4=create_model('rf')
# Out:
# <style  type="text/css" >
# #T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col0,#T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col1,#T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col2,#T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col3,#T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col4,#T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col5,#T_f3e3b3dc_63c4_11eb_86c9_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_f3e3b3dc_63c4_11eb_86c9_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
# Out:
# <style  type="text/css" >
# #T_cf261b14_63c6_11eb_9d42_acde48001122row10_col0,#T_cf261b14_63c6_11eb_9d42_acde48001122row10_col1,#T_cf261b14_63c6_11eb_9d42_acde48001122row10_col2,#T_cf261b14_63c6_11eb_9d42_acde48001122row10_col3,#T_cf261b14_63c6_11eb_9d42_acde48001122row10_col4,#T_cf261b14_63c6_11eb_9d42_acde48001122row10_col5,#T_cf261b14_63c6_11eb_9d42_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_cf261b14_63c6_11eb_9d42_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tune_model1=tune_model(model1)
tune_model2=tune_model(model2)
tune_model3=tune_model(model3)
tune_model4=tune_model(model4)
# Out:
# <style  type="text/css" >
# #T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col0,#T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col1,#T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col2,#T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col3,#T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col4,#T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col5,#T_7bf48db4_63c5_11eb_9ce9_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_7bf48db4_63c5_11eb_9ce9_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_5608487e_572d_11eb_9497_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
final_lgbm = finalize_model(tune_lgbm)

# %%
lgbm_predictions = predict_model(tune_lgbm, data=df_test_trans)

# %%
ensemble = blend_models([tune_lgbm, tune_cat])
# Out:
# <style  type="text/css" >
# #T_89675174_572d_11eb_acd4_acde48001122row10_col0,#T_89675174_572d_11eb_acd4_acde48001122row10_col1,#T_89675174_572d_11eb_acd4_acde48001122row10_col2,#T_89675174_572d_11eb_acd4_acde48001122row10_col3,#T_89675174_572d_11eb_acd4_acde48001122row10_col4,#T_89675174_572d_11eb_acd4_acde48001122row10_col5,#T_89675174_572d_11eb_acd4_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_89675174_572d_11eb_acd4_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
ensemble_predictions = predict_model(tune_lgbm, data=df_test_trans)

# %%
sample=pd.read_csv('sample_submit.csv',header=None,names=('number','state'))

# %%
sample['state']=cat_predictions['Label']

# %%
ensemble_predictions
# Out:
#        goal1  goal2 country  duration   category1       category2  \
# 0          1   1000      US        60       dance    performances
# 1       8001   9000      US        30      crafts        printing
# 2       9001  10000      US        60      design  product design
# 3       1001   2000      US        30  technology        software
# 4       4001   5000      US        59  technology        software
# ...      ...    ...     ...       ...         ...             ...
# 10539   9001  10000      US        30        food          drinks
# 10540      1   1000      US        29        food     small batch
# 10541   1001   2000      US        27      crafts         pottery
# 10542   2001   3000      US        30      design  graphic design
# 10543   1001   2000      US        30     fashion   ready-to-wear
#
#                                             html_content  Label   Score
# 0      We are presenting two new important works feat...      1  0.6365
# ...

# %%
lgbm_predictions
# Out:
#        goal1  goal2 country  duration   category1       category2  \
# 0          1   1000      US        60       dance    performances
# 1       8001   9000      US        30      crafts        printing
# 2       9001  10000      US        60      design  product design
# 3       1001   2000      US        30  technology        software
# 4       4001   5000      US        59  technology        software
# ...      ...    ...     ...       ...         ...             ...
# 10539   9001  10000      US        30        food          drinks
# 10540      1   1000      US        29        food     small batch
# 10541   1001   2000      US        27      crafts         pottery
# 10542   2001   3000      US        30      design  graphic design
# 10543   1001   2000      US        30     fashion   ready-to-wear
#
#                                             html_content  Label   Score
# 0      We are presenting two new important works feat...      1  0.6365
# ...

# %%
cat_predictions
# Out:
#        goal1  goal2 country  duration   category1       category2  \
# 0          1   1000      US        60       dance    performances
# 1       8001   9000      US        30      crafts        printing
# 2       9001  10000      US        60      design  product design
# 3       1001   2000      US        30  technology        software
# 4       4001   5000      US        59  technology        software
# ...      ...    ...     ...       ...         ...             ...
# 10539   9001  10000      US        30        food          drinks
# 10540      1   1000      US        29        food     small batch
# 10541   1001   2000      US        27      crafts         pottery
# 10542   2001   3000      US        30      design  graphic design
# 10543   1001   2000      US        30     fashion   ready-to-wear
#
#                                             html_content  Label   Score
# 0      We are presenting two new important works feat...      1  0.5046
# ...

# %%
sample.to_csv('submit_cat_trans.csv',index=False,header=None)

# %%
from pycaret.nlp import *

# %%
exp_nlp101 = setup(data = df_train_trans, target = 'html_content', session_id = 123)
# Out:
# <style  type="text/css" >
# </style><table id="T_38aed81c_5a55_11eb_93a6_acde48001122" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_38aed81c_5a55_11eb_93a6_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_38aed81c_5a55_11eb_93a6_acde48001122row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                                 <td id="T_38aed81c_5a55_11eb_93a6_acde48001122row1_col0" class="data row1 col0" >Documents</td>
#                         <td id="T_38aed81c_5a55_11eb_93a6_acde48001122row1_col1" class="data row1 col1" >10545</td>
#             </tr>
#             <tr>
#                                 <td id="T_38aed81c_5a55_11eb_93a6_acde48001122row2_col0" class="data row2 col0" >Vocab Size</td>
# ...

# %%
lda = create_model('nmf')

# %%
lda_results = assign_model(lda)
# Out:
# IntProgress(value=0, description='Processing: ', max=10550)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     21:52:51
# Status     . . . . . . . . . . . . . . . . . .         Creating Topic Model
# Step       . . . . . . . . . . . . . . . . . .  Fitting Model With 4 Topics
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
tuned_classification = tune_model(model = 'nmf', multi_core = True, supervised_target = 'state')
# Out:
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
evaluate_model(lda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
plot_model(lda, plot = 'frequency')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# ...

# %%
lda_results[:10]
# Out:
#    goal1  goal2 country  duration     category1        category2  \
# 0   4001   5000      CH        29    publishing      young adult
# 1   3001   4000      NL        34       fashion    ready-to-wear
# 2  19001  20000      US        30          food           spaces
# 3   2001   3000      US        41    technology      3d printing
# 4   2001   3000      GB        29    technology  diy electronics
# 5      1   1000      US        19   photography         fine art
# 6   3001   4000      GB        59       fashion          apparel
# 7      1   1000      US        20           art      mixed media
# 8   2001   3000      US        28    publishing      periodicals
# 9   1001   2000      GB        21  film & video      documentary
#
#                                         html_content  state   Topic_0  \
# 0  writer emigrate videogame fanatic part entire ...      0  0.000000
# 1  decide create brand clothe speak mock war dict...      0  0.000085
# ...

# %%
sample=pd.read_csv('sample_submit.csv',header=None,names=('number','state'))
sample.head()
# Out:
#    number  state
# 0   10545      1
# 1   10546      0
# 2   10547      1
# 3   10548      0
# 4   10549      0

# %%
sample['state']=stack_prediction['Label']
sample.to_csv('stacking_BERT.csv',index=False,header=None)

# %%
BERT=pd.read_csv('BERT.csv',header=None,names=('number','state'))
BERT=np.where(BERT['state']>=0.6,1,0)

# %%
for i in range(len(stack_prediction)):
    if stack_prediction['Score'][i]<=0.6:
        stack_prediction['Label'][i]=BERT[i]
stack_prediction
# Out:
#          id   goal country  duration   category1       category2  \
# 0         1   1000      US        60       dance    performances
# 1      8001   9000      US        30      crafts        printing
# 2      9001  10000      US        60      design  product design
# 3      1001   2000      US        30  technology        software
# 4      4001   5000      US        59  technology        software
# ...     ...    ...     ...       ...         ...             ...
# 10539  9001  10000      US        30        food          drinks
# 10540     1   1000      US        29        food     small batch
# 10541  1001   2000      US        27      crafts         pottery
# 10542  2001   3000      US        30      design  graphic design
# 10543  1001   2000      US        30     fashion   ready-to-wear
#
#                                             html_content  Label     Score
# 0      We are presenting two new important works feat...      0  0.636800
# ...

# %%
BERT
# Out:
# array([0, 1, 1, ..., 1, 1, 0])
